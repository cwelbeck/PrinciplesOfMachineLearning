# %%
# Import the Dataset

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy.random as nr
import math

# %matplotlib inline

# %%
# Load the Dataset
AdvWorksCusts = pd.read_csv('AdvWorksCustsPrep4.csv', header=None)

# %%
# Check Datatypes for each Column
AdvWorksCusts.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# 12    object
# 13    object
# 14    object
# dtype: object

# %%
AdvWorksCusts.head()
# Out:
#            0                  1                  2           3           4   \
# 0  CustomerID  StateProvinceName  CountryRegionName  PostalCode  BirthDate1
# 1       11000         Queensland          Australia        4700    4/8/1966
# 2       11001           Victoria          Australia        3198   5/14/1965
# 3       11002           Tasmania          Australia        7001   8/12/1965
# 4       11003    New South Wales          Australia        2113   2/15/1968
#
#              5           6             7       8              9   \
# 0  BirthDateAge   Education    Occupation  Gender  MaritalStatus
# 1            54  Bachelors   Professional       M              M
# 2            55  Bachelors   Professional       M              S
# 3            54  Bachelors   Professional       M              M
# 4            52  Bachelors   Professional       F              S
#
#               10               11                    12             13  \
# ...

# %%
# Make first row the header

new_header = AdvWorksCusts.iloc[0] #grab the first row for the header
AdvWorksCusts = AdvWorksCusts[1:] #take the data less the header row
AdvWorksCusts.columns = new_header #set the header row as the df header

AdvWorksCusts.head()
# Out:
# 0 CustomerID StateProvinceName CountryRegionName PostalCode BirthDate1  \
# 1      11000        Queensland         Australia       4700   4/8/1966
# 2      11001          Victoria         Australia       3198  5/14/1965
# 3      11002          Tasmania         Australia       7001  8/12/1965
# 4      11003   New South Wales         Australia       2113  2/15/1968
# 5      11004   New South Wales         Australia       2500   8/8/1968
#
# 0 BirthDateAge   Education    Occupation Gender MaritalStatus HomeOwnerFlag  \
# 1           54  Bachelors   Professional      M             M             1
# 2           55  Bachelors   Professional      M             S             0
# 3           54  Bachelors   Professional      M             M             1
# 4           52  Bachelors   Professional      F             S             0
# 5           51  Bachelors   Professional      F             S             1
#
# 0 NumberCarsOwned NumberChildrenAtHome TotalChildren YearlyIncome
# ...

# %%
# Check Datatypes for each Column
AdvWorksCusts.dtypes
# Out:
# 0
# CustomerID              object
# StateProvinceName       object
# CountryRegionName       object
# PostalCode              object
# BirthDate1              object
# BirthDateAge            object
# Education               object
# Occupation              object
# Gender                  object
# MaritalStatus           object
# HomeOwnerFlag           object
# NumberCarsOwned         object
# NumberChildrenAtHome    object
# TotalChildren           object
# YearlyIncome            object
# dtype: object

# %%
# Remove Duplicate Rows

print('Before Removing Duplicate Rows') 
print(AdvWorksCusts.shape)
AdvWorksCusts.drop_duplicates(subset = 'CustomerID', keep = 'first', inplace = True)
print('After Removing Duplicate Rows')
print(AdvWorksCusts.shape)
print(AdvWorksCusts.CustomerID.unique().shape)
# Out:
# Before Removing Duplicate Rows
# (16404, 15)
# After Removing Duplicate Rows
# (16404, 15)
# (16404,)

# %%
AdvWorksCusts.head()
# Out:
# 0 CustomerID StateProvinceName CountryRegionName PostalCode BirthDate1  \
# 1      11000        Queensland         Australia       4700   4/8/1966
# 2      11001          Victoria         Australia       3198  5/14/1965
# 3      11002          Tasmania         Australia       7001  8/12/1965
# 4      11003   New South Wales         Australia       2113  2/15/1968
# 5      11004   New South Wales         Australia       2500   8/8/1968
#
# 0 BirthDateAge   Education    Occupation Gender MaritalStatus HomeOwnerFlag  \
# 1           54  Bachelors   Professional      M             M             1
# 2           55  Bachelors   Professional      M             S             0
# 3           54  Bachelors   Professional      M             M             1
# 4           52  Bachelors   Professional      F             S             0
# 5           51  Bachelors   Professional      F             S             1
#
# 0 NumberCarsOwned NumberChildrenAtHome TotalChildren YearlyIncome
# ...

# %%
# Check Datatypes for each Column
AdvWorksCusts.dtypes
# Out:
# 0
# CustomerID              object
# StateProvinceName       object
# CountryRegionName       object
# PostalCode              object
# BirthDate1              object
# BirthDateAge            object
# Education               object
# Occupation              object
# Gender                  object
# MaritalStatus           object
# HomeOwnerFlag           object
# NumberCarsOwned         object
# NumberChildrenAtHome    object
# TotalChildren           object
# YearlyIncome            object
# dtype: object

# %%
# Drop Columns not needed

AdvWorksCusts = AdvWorksCusts.drop(['CustomerID','StateProvinceName','BirthDate1'], axis=1)
AdvWorksCusts.head()
# Out:
# 0 CountryRegionName PostalCode BirthDateAge   Education    Occupation Gender  \
# 1         Australia       4700           54  Bachelors   Professional      M
# 2         Australia       3198           55  Bachelors   Professional      M
# 3         Australia       7001           54  Bachelors   Professional      M
# 4         Australia       2113           52  Bachelors   Professional      F
# 5         Australia       2500           51  Bachelors   Professional      F
#
# 0 MaritalStatus HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome  \
# 1             M             1               0                    0
# 2             S             0               1                    3
# 3             M             1               1                    3
# 4             S             0               1                    0
# 5             S             1               4                    5
#
# 0 TotalChildren YearlyIncome
# 1             2       137947
# 2             3       101141
# ...

# %%
# Check Datatypes for each Column
AdvWorksCusts.dtypes
# Out:
# 0
# CountryRegionName       object
# PostalCode              object
# BirthDateAge            object
# Education               object
# Occupation              object
# Gender                  object
# MaritalStatus           object
# HomeOwnerFlag           object
# NumberCarsOwned         object
# NumberChildrenAtHome    object
# TotalChildren           object
# YearlyIncome            object
# dtype: object

# %%
# Check for Missing Values
AdvWorksCusts.isnull()
# Out:
# 0      CountryRegionName  PostalCode  BirthDateAge  Education  Occupation  \
# 1                  False       False         False      False       False
# 2                  False       False         False      False       False
# 3                  False       False         False      False       False
# 4                  False       False         False      False       False
# 5                  False       False         False      False       False
# 6                  False       False         False      False       False
# 7                  False       False         False      False       False
# 8                  False       False         False      False       False
# 9                  False       False         False      False       False
# 10                 False       False         False      False       False
# 11                 False       False         False      False       False
# 12                 False       False         False      False       False
# ...

# %%
# Count Missing Values Per String Columns

for col in AdvWorksCusts.columns:
    if AdvWorksCusts[col].dtype == object:
        count = 0
        count = [count + 1 for x in AdvWorksCusts[col] if x == 'NaN']
        print(col + ' ' + str(sum(count)))
# Out:
# CountryRegionName 0
# PostalCode 0
# BirthDateAge 0
# Education 0
# Occupation 0
# Gender 0
# MaritalStatus 0
# HomeOwnerFlag 0
# NumberCarsOwned 0
# NumberChildrenAtHome 0
# TotalChildren 0
# YearlyIncome 0

# %%
# Replace British Columbia, Alberta And Englands Zip-Codes

# AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace(25.0, "Twenty five")
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V0', 10000)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V2L3W8', 10001)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V2M1N7', 10002)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V2M1P1', 10003)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V2M1S6', 10004)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V2W 1W2', 10005)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V3A 4R2', 10006)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V3J 6Z3', 10007)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V3L 1E7', 10008)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V3L 1H4', 10009)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V6B 3P7', 10010)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V7L 4J4', 10011)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V8P', 10012)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V8V', 10013)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V8X', 10014)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V8Y 1L1', 10015)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V8Z 4N5', 10016)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V9', 10017)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V9B 2C3', 10018)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('V9B 5T2', 10019)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('AS23', 20000)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('B29 6SL', 20001)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('BD1 4SJ', 20002)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('C2H 7AU', 20003)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('CB4 4BZ', 20004)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('CM11', 20005)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('E17 6JF', 20006)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('EC1R 0DU', 20007)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('EM15', 20008)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('GA10', 20009)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('GL50', 20010)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('GL7 1RY', 20011)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('HP10 9QY', 20012)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('KB9', 20013)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('L4 4HB', 20014)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('LA1 1LN', 20015)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('LE18', 20016)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('MK8 8DF', 20017)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('MK8 8ZD', 20018)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('NT20', 20019)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('OX1', 20021)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('OX14 4SE', 20021)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('OX16 8RS', 20022)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('PB12', 20023)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('PE17', 20024)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('RG11 5TP', 20025)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('RG12 8TB', 20026)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('RG24 8PL', 20027)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('RG41 1QW', 20028)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('RG7 5H7', 20029)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('RH15 9UD', 20030)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('SE1 8HL', 20031)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('SL4 1RH', 20032)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('RH15 9UD', 20030)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('SL67RJ', 20031)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('SW19 3RU', 20032)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('SW1P 2NU', 20033)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('SW6 SBY', 20034)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('SW8 1XD', 20035)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('SW8 4BG', 20036)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('TY31', 20037)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('W10 6BL', 20038)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('W1N 9FA', 20039)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('W1V 5RN', 20040)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('W1X3SE', 20041)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('W1Y 3RA', 20042)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('WA1', 20043)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('WA1 4SY', 20044)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('WA3', 20045)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('WA3 7BH', 20046)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('Y024 1GF', 20047)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('Y03 4TN', 20048)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('YO15', 20049)
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].replace('T2P 2G8', 20050)

# %%
AdvWorksCusts.head(20)
# Out:
# 0  CountryRegionName PostalCode BirthDateAge        Education      Occupation  \
# 1          Australia       4700           54       Bachelors     Professional
# 2          Australia       3198           55       Bachelors     Professional
# 3          Australia       7001           54       Bachelors     Professional
# 4          Australia       2113           52       Bachelors     Professional
# 5          Australia       2500           51       Bachelors     Professional
# 6          Australia       4169           54       Bachelors     Professional
# 7          Australia       2036           54       Bachelors     Professional
# 8          Australia       3280           56       Bachelors     Professional
# 9          Australia       3550           55       Bachelors     Professional
# 10         Australia       4655           56       Bachelors     Professional
# 11         Australia       4169           56       Bachelors     Professional
# ...

# %%
# Extract the first 5 strings from the ZipCode
#sales_data["zip_code"] = sales_data["zip_code"].str[:5]
AdvWorksCusts["PostalCode"] = AdvWorksCusts["PostalCode"].str[:5]

# %%
# Check Datatypes for each Column
AdvWorksCusts.dtypes
# Out:
# 0
# CountryRegionName       object
# PostalCode              object
# BirthDateAge            object
# Education               object
# Occupation              object
# Gender                  object
# MaritalStatus           object
# HomeOwnerFlag           object
# NumberCarsOwned         object
# NumberChildrenAtHome    object
# TotalChildren           object
# YearlyIncome            object
# dtype: object

# %%
AdvWorksCusts.head(20)
# Out:
# 0  CountryRegionName PostalCode BirthDateAge        Education      Occupation  \
# 1          Australia       4700           54       Bachelors     Professional
# 2          Australia       3198           55       Bachelors     Professional
# 3          Australia       7001           54       Bachelors     Professional
# 4          Australia       2113           52       Bachelors     Professional
# 5          Australia       2500           51       Bachelors     Professional
# 6          Australia       4169           54       Bachelors     Professional
# 7          Australia       2036           54       Bachelors     Professional
# 8          Australia       3280           56       Bachelors     Professional
# 9          Australia       3550           55       Bachelors     Professional
# 10         Australia       4655           56       Bachelors     Professional
# 11         Australia       4169           56       Bachelors     Professional
# ...

# %%
# Convert Columns to Numeric

cols = ['PostalCode', 'BirthDateAge', 'HomeOwnerFlag', 'NumberCarsOwned', 'NumberChildrenAtHome',
          'TotalChildren', 'YearlyIncome']

for column in cols:
    AdvWorksCusts[column] = pd.to_numeric(AdvWorksCusts[column])
AdvWorksCusts[cols].dtypes
# Out:
# 0
# PostalCode              float64
# BirthDateAge              int64
# HomeOwnerFlag             int64
# NumberCarsOwned           int64
# NumberChildrenAtHome      int64
# TotalChildren             int64
# YearlyIncome              int64
# dtype: object

# %%
# Check Datatypes for each Column
AdvWorksCusts.dtypes
# Out:
# 0
# CountryRegionName        object
# PostalCode              float64
# BirthDateAge              int64
# Education                object
# Occupation               object
# Gender                   object
# MaritalStatus            object
# HomeOwnerFlag             int64
# NumberCarsOwned           int64
# NumberChildrenAtHome      int64
# TotalChildren             int64
# YearlyIncome              int64
# dtype: object

# %%
#AdvWorksCusts.shape()
AdvWorksCusts.describe()
# Out:
# 0        PostalCode  BirthDateAge  HomeOwnerFlag  NumberCarsOwned  \
# count  13297.000000  16404.000000   16404.000000     16404.000000
# mean   65122.144769     57.856498       0.674104         1.499756
# std    39215.657199     11.250557       0.468723         1.139135
# min     1002.000000     39.000000       0.000000         0.000000
# 25%    12171.000000     49.000000       0.000000         1.000000
# 50%    91364.000000     56.000000       1.000000         2.000000
# 75%    94704.000000     65.000000       1.000000         2.000000
# max    99362.000000    109.000000       1.000000         4.000000
#
# 0      NumberChildrenAtHome  TotalChildren   YearlyIncome
# count          16404.000000   16404.000000   16404.000000
# mean               0.991100       2.004511   78128.531517
# std                1.514278       1.682318   39726.533060
# min                0.000000       0.000000    9482.000000
# 25%                0.000000       0.000000   47811.750000
# ...

# %%
# Check for Missing Values
AdvWorksCusts.isnull()
# Out:
# 0      CountryRegionName  PostalCode  BirthDateAge  Education  Occupation  \
# 1                  False       False         False      False       False
# 2                  False       False         False      False       False
# 3                  False       False         False      False       False
# 4                  False       False         False      False       False
# 5                  False       False         False      False       False
# 6                  False       False         False      False       False
# 7                  False       False         False      False       False
# 8                  False       False         False      False       False
# 9                  False       False         False      False       False
# 10                 False       False         False      False       False
# 11                 False       False         False      False       False
# 12                 False       False         False      False       False
# ...

# %%
# Out:
# CountryRegionName 0
# Education 0
# Occupation 0
# Gender 0
# MaritalStatus 0

# %%
# Drop Row with Missing Data
# AdvWorksCusts.dropna(axis = 0, inplace = True)
# Out:
# 0
# HomeOwnerFlag           int64
# NumberCarsOwned         int64
# NumberChildrenAtHome    int64
# TotalChildren           int64
# YearlyIncome            int64
# dtype: object

# %%
# Check Datatypes for each Column
AdvWorksCusts.dtypes
# Out:
# 0
# CountryRegionName        object
# PostalCode              float64
# BirthDateAge              int64
# Education                object
# Occupation               object
# Gender                   object
# MaritalStatus            object
# HomeOwnerFlag             int64
# NumberCarsOwned           int64
# NumberChildrenAtHome      int64
# TotalChildren             int64
# YearlyIncome              int64
# dtype: object
